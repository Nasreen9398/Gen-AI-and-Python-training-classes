# %%
undersatnding the variables in python

# %%
a=2
b=4
c=a+b
print(c)
# Out:
# 6

# %%
Rules for declaring the variables in Python :

# %%
Rule1 : No space while declaring the variable name

# %%
first_name="Nasreen"
print(first_name)
# Out:
# Nasreen

# %%
Rule2 : A variable should not start with the number,but the number will be in middle at last in will acceptable

# %%
name1="nasreen"
print(name1)
# Out:
# nasreen

# %%
Rule 3:  a variable name should not contain special characters

# %%
name@="nasreen"
print(name@)
# Out:
#   Cell In[4], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
Introduction to datatypes in python :
strins
integer,float
list
tuple
dictionary

# %%
Classifications of datatypes :
Broadly datatypes are classified into 2 catagories :
1)Mutable-->which can edit/alter--->flexible in nature
2)Immutable-->which we cannot edit/alter--->fixed in nature
