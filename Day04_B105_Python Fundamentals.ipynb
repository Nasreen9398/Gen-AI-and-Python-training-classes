# %%
Introduction to list datatypes:

# %%
defination: A list is a collection of items declared in a particular order.
classified: It is classified as mutuble datatype
We declare by using[]

# %%
students  =["akila","raji","shaheena","masthani"]
print(students)
# Out:
# ['akila', 'raji', 'shaheena', 'masthani']

# %%
type(students)
# Out:
# list

# %%
Introduction to indexing:

# %%
print(students[0]) # to get the akhila by using index number
# Out:
# akila

# %%
list methods:

# %%
students.append("laskmi") # to attach at end of the list
print students
# Out:
# ['akila', 'raji', 'shaheena', 'masthani', 'lakshmi']

# %%
students.insert(1,"mothi") # to insert at particular index
print(students)
# Out:
# ['akila', 'mothi', 'mothi', 'mothi', 'raji', 'shaheena', 'masthani', 'lakshmi']

# %%
students[1]="fathima"
print(students)
# Out:
# ['akila', 'fathima', 'mothi', 'mothi', 'raji', 'shaheena', 'masthani', 'lakshmi']

# %%
del students[2]
print(students)
# Out:
# ['akila', 'fathima', 'mothi', 'shaheena', 'masthani', 'lakshmi']
