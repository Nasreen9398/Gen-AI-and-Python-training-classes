# %%
Continuation with string datatype:

# %%
Introduction to f string:

# %%
FirstName="Nasreen"
LastName="Shaik"
print(f"{FirstName} {LastName}")
print(f"{LastName} {FirstName}")
message=f" keep the work continous, {LastName} {FirstName}"
print(message.lstrip())
# Out:
# Nasreen Shaik
# Shaik Nasreen
# keep the work continous, Shaik Nasreen

# %%
# if we want to get the full name we use syntax

# %%
#general syntax of f string

# %%
message = f"custom message {place holder1} {place holder2}......{place holdern}"

# %%
Undersatnding the concept of whitespaces:

# %%
print("fav_progPythonCjavaC++Swiftjavascript")
# Out:
# fav_progPythonCjavaC++Swiftjavascript

# %%
print("fav_prog:\nPython\nC\njava\nC++\nSwift\njavascript")
# Out:
# fav_prog:
# Python
# C
# java
# C++
# Swift
# javascript

# %%
print("fav_prog:\n\tPython\n\tC\n\tjava\n\tC++\n\tSwift\n\tjavascript")
# Out:
# fav_prog:
# 	Python
# 	C
# 	java
# 	C++
# 	Swift
# 	javascript

# %%
\n--->new line delimiter

# %%
\t--->tab delimeter

# %%
about whitespaces while printing:

# %%
name="   Naseeen"
print(name)
print(name.lstrip())
# Out:
#    Naseeen
# Naseeen

# %%
name="Nasreen    "
print(name)
print(name.rstrip())
# Out:
# Nasreen
# Nasreen
